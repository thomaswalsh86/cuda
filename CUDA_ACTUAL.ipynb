# %% [markdown]
# <a href="https://colab.research.google.com/github/thomaswalsh86/cuda/blob/main/CUDA_ACTUAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# Collecting git+https://github.com/andreinechaev/nvcc4jupyter.git
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-853mucdc
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-853mucdc
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit 28f872a2f99a1b201bcd0db14fdbc5a496b9bfd7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# %load_ext nvcc4jupyter
# Out:
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmps1yajyfa".

# %%
# %%cuda
# #include <stdio.h>
# #include <cuda_runtime.h>
#
# __global__ void hello_from_gpu() {
#     printf("Hello World from GPU! Thread %d in Block %d\n", threadIdx.x, blockIdx.x);
# }
#
# int main(void) {
#     printf("Starting CUDA program on Tesla T4...\n");
#     fflush(stdout);
#
#     // Launch kernel with multiple threads to increase chance of output
#     hello_from_gpu<<<2, 3>>>();
#
#     // Proper synchronization with error checking
#     cudaError_t syncError = cudaDeviceSynchronize();
#     if (syncError != cudaSuccess) {
#         printf("CUDA sync error: %s\n", cudaGetErrorString(syncError));
#         fflush(stdout);
#     }
#
#     cudaError_t kernelError = cudaGetLastError();
#     if (kernelError != cudaSuccess) {
#         printf("Kernel launch error: %s\n", cudaGetErrorString(kernelError));
#         fflush(stdout);
#     }
#
#     printf("Program completed successfully!\n");
#     fflush(stdout);
#     return 0;
# }
# Out:
# Starting CUDA program on Tesla T4...
# Hello World from GPU! Thread 0 in Block 0
# Hello World from GPU! Thread 1 in Block 0
# Hello World from GPU! Thread 2 in Block 0
# Hello World from GPU! Thread 0 in Block 1
# Hello World from GPU! Thread 1 in Block 1
# Hello World from GPU! Thread 2 in Block 1
# Program completed successfully!

# %%
# %%writefile simulation_test.cu
# #include <stdio.h>
# #include <cuda_runtime.h>
# #include <math.h>
#
# // N-body simulation (simplified)
# struct Body {
#     float x, y, z;
#     float vx, vy, vz;
#     float mass;
# };
#
# __global__ void nbody_simulation(Body *bodies, int n, float dt) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     if (i >= n) return;
#
#     float fx = 0.0f, fy = 0.0f, fz = 0.0f;
#
#     // Calculate gravitational forces from all other bodies
#     for (int j = 0; j < n; j++) {
#         if (i == j) continue;
#
#         float dx = bodies[j].x - bodies[i].x;
#         float dy = bodies[j].y - bodies[i].y;
#         float dz = bodies[j].z - bodies[i].z;
#
#         float dist_sq = dx*dx + dy*dy + dz*dz + 1e-10f; // Softening
#         float dist = sqrtf(dist_sq);
#         float force = bodies[i].mass * bodies[j].mass / dist_sq;
#
#         fx += force * dx / dist;
#         fy += force * dy / dist;
#         fz += force * dz / dist;
#     }
#
#     // Update velocities and positions
#     bodies[i].vx += fx / bodies[i].mass * dt;
#     bodies[i].vy += fy / bodies[i].mass * dt;
#     bodies[i].vz += fz / bodies[i].mass * dt;
#
#     bodies[i].x += bodies[i].vx * dt;
#     bodies[i].y += bodies[i].vy * dt;
#     bodies[i].z += bodies[i].vz * dt;
# }
#
# int main() {
#     printf("=== REAL-WORLD SIMULATION TEST ===\n\n");
#
#     int n_bodies = 4096;
#     int iterations = 10;
#
#     printf("Running N-body simulation with %d bodies for %d iterations\n\n",
#            n_bodies, iterations);
#
#     Body *h_bodies = new Body[n_bodies];
#     Body *d_bodies;
#
#     // Initialize random bodies
#     for (int i = 0; i < n_bodies; i++) {
#         h_bodies[i].x = (float)rand() / RAND_MAX * 100.0f - 50.0f;
#         h_bodies[i].y = (float)rand() / RAND_MAX * 100.0f - 50.0f;
#         h_bodies[i].z = (float)rand() / RAND_MAX * 100.0f - 50.0f;
#         h_bodies[i].vx = (float)rand() / RAND_MAX * 2.0f - 1.0f;
#         h_bodies[i].vy = (float)rand() / RAND_MAX * 2.0f - 1.0f;
#         h_bodies[i].vz = (float)rand() / RAND_MAX * 2.0f - 1.0f;
#         h_bodies[i].mass = (float)rand() / RAND_MAX * 10.0f + 1.0f;
#     }
#
#     cudaMalloc(&d_bodies, n_bodies * sizeof(Body));
#
#     cudaEvent_t start, stop;
#     cudaEventCreate(&start);
#     cudaEventCreate(&stop);
#
#     cudaEventRecord(start);
#
#     for (int iter = 0; iter < iterations; iter++) {
#         cudaMemcpy(d_bodies, h_bodies, n_bodies * sizeof(Body), cudaMemcpyHostToDevice);
#
#         int blockSize = 256;
#         int numBlocks = (n_bodies + blockSize - 1) / blockSize;
#
#         nbody_simulation<<<numBlocks, blockSize>>>(d_bodies, n_bodies, 0.01f);
#         cudaDeviceSynchronize();
#
#         cudaMemcpy(h_bodies, d_bodies, n_bodies * sizeof(Body), cudaMemcpyDeviceToHost);
#
#         if (iter % 2 == 0) {
#             printf("Iteration %d/%d completed\n", iter + 1, iterations);
#         }
#     }
#
#     cudaEventRecord(stop);
#     cudaEventSynchronize(stop);
#
#     float milliseconds;
#     cudaEventElapsedTime(&milliseconds, start, stop);
#
#     printf("\nSimulation Results:\n");
#     printf("Total time: %.2f ms\n", milliseconds);
#     printf("Time per iteration: %.2f ms\n", milliseconds / iterations);
#     printf("Bodies processed per second: %.2f million\n",
#            (n_bodies * iterations) / (milliseconds / 1000.0) / 1e6);
#
#     // Calculate center of mass to verify simulation
#     float total_mass = 0.0f;
#     float com_x = 0.0f, com_y = 0.0f, com_z = 0.0f;
#
#     for (int i = 0; i < n_bodies; i++) {
#         total_mass += h_bodies[i].mass;
#         com_x += h_bodies[i].x * h_bodies[i].mass;
#         com_y += h_bodies[i].y * h_bodies[i].mass;
#         com_z += h_bodies[i].z * h_bodies[i].mass;
#     }
#
#     com_x /= total_mass;
#     com_y /= total_mass;
#     com_z /= total_mass;
#
#     printf("Center of mass: (%.2f, %.2f, %.2f)\n", com_x, com_y, com_z);
#
#     // Cleanup
#     delete[] h_bodies;
#     cudaFree(d_bodies);
#     cudaEventDestroy(start);
#     cudaEventDestroy(stop);
#
#     printf("\n=== SIMULATION TEST COMPLETE ===\n");
#     return 0;
# }
# Out:
# Overwriting simulation_test.cu

# %%
# !nvcc -arch=sm_75 -o simulation_test simulation_test.cu && ./simulation_test
# Out:
# === REAL-WORLD SIMULATION TEST ===
#
# Running N-body simulation with 4096 bodies for 10 iterations
#
# Iteration 1/10 completed
# Iteration 3/10 completed
# Iteration 5/10 completed
# Iteration 7/10 completed
# Iteration 9/10 completed
#
# Simulation Results:
# Total time: 37.48 ms
# Time per iteration: 3.75 ms
# Bodies processed per second: 1.09 million
# Center of mass: (0.18, -0.94, -0.70)
#
# === SIMULATION TEST COMPLETE ===

# %%
# !sudo apt-get install cuda-toolkit-12-4 -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   ca-certificates-java cuda-cccl-12-4 cuda-command-line-tools-12-4
#   cuda-compiler-12-4 cuda-crt-12-4 cuda-cudart-12-4 cuda-cudart-dev-12-4
#   cuda-cuobjdump-12-4 cuda-cupti-12-4 cuda-cupti-dev-12-4 cuda-cuxxfilt-12-4
#   cuda-documentation-12-4 cuda-driver-dev-12-4 cuda-gdb-12-4
#   cuda-libraries-12-4 cuda-libraries-dev-12-4 cuda-nsight-12-4
#   cuda-nsight-compute-12-4 cuda-nsight-systems-12-4 cuda-nvcc-12-4
#   cuda-nvdisasm-12-4 cuda-nvml-dev-12-4 cuda-nvprof-12-4 cuda-nvprune-12-4
#   cuda-nvrtc-12-4 cuda-nvrtc-dev-12-4 cuda-nvtx-12-4 cuda-nvvm-12-4
#   cuda-nvvp-12-4 cuda-opencl-12-4 cuda-opencl-dev-12-4 cuda-profiler-api-12-4
#   cuda-sanitizer-12-4 cuda-toolkit-12-4-config-common cuda-tools-12-4
#   cuda-visual-tools-12-4 default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra gds-tools-12-4 java-common libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-12-4 libcublas-dev-12-4 libcufft-12-4
#   libcufft-dev-12-4 libcufile-12-4 libcufile-dev-12-4 libcurand-12-4
#   libcurand-dev-12-4 libcusolver-12-4 libcusolver-dev-12-4 libcusparse-12-4
#   libcusparse-dev-12-4 libnpp-12-4 libnpp-dev-12-4 libnvfatbin-12-4
#   libnvfatbin-dev-12-4 libnvjitlink-12-4 libnvjitlink-dev-12-4 libnvjpeg-12-4
#   libnvjpeg-dev-12-4 libpcsclite1 libtinfo5 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxtst6 libxxf86dga1
#   nsight-compute-2024.1.1 nsight-systems-2023.4.4 openjdk-11-jre
#   openjdk-11-jre-headless x11-utils
# Suggested packages:
#   pcscd libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   ca-certificates-java cuda-cccl-12-4 cuda-command-line-tools-12-4
#   cuda-compiler-12-4 cuda-crt-12-4 cuda-cudart-12-4 cuda-cudart-dev-12-4
#   cuda-cuobjdump-12-4 cuda-cupti-12-4 cuda-cupti-dev-12-4 cuda-cuxxfilt-12-4
#   cuda-documentation-12-4 cuda-driver-dev-12-4 cuda-gdb-12-4
#   cuda-libraries-12-4 cuda-libraries-dev-12-4 cuda-nsight-12-4
#   cuda-nsight-compute-12-4 cuda-nsight-systems-12-4 cuda-nvcc-12-4
#   cuda-nvdisasm-12-4 cuda-nvml-dev-12-4 cuda-nvprof-12-4 cuda-nvprune-12-4
#   cuda-nvrtc-12-4 cuda-nvrtc-dev-12-4 cuda-nvtx-12-4 cuda-nvvm-12-4
#   cuda-nvvp-12-4 cuda-opencl-12-4 cuda-opencl-dev-12-4 cuda-profiler-api-12-4
#   cuda-sanitizer-12-4 cuda-toolkit-12-4 cuda-toolkit-12-4-config-common
#   cuda-tools-12-4 cuda-visual-tools-12-4 default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra gds-tools-12-4 java-common
#   libatk-wrapper-java libatk-wrapper-java-jni libcublas-12-4
#   libcublas-dev-12-4 libcufft-12-4 libcufft-dev-12-4 libcufile-12-4
#   libcufile-dev-12-4 libcurand-12-4 libcurand-dev-12-4 libcusolver-12-4
#   libcusolver-dev-12-4 libcusparse-12-4 libcusparse-dev-12-4 libnpp-12-4
#   libnpp-dev-12-4 libnvfatbin-12-4 libnvfatbin-dev-12-4 libnvjitlink-12-4
#   libnvjitlink-dev-12-4 libnvjpeg-12-4 libnvjpeg-dev-12-4 libpcsclite1
#   libtinfo5 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0
#   libxtst6 libxxf86dga1 nsight-compute-2024.1.1 nsight-systems-2023.4.4
#   openjdk-11-jre openjdk-11-jre-headless x11-utils
# 0 upgraded, 83 newly installed, 0 to remove and 41 not upgraded.
# Need to get 3,068 MB of archives.
# After this operation, 6,781 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 java-common all 0.72build2 [6,782 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcsclite1 amd64 1.9.5-3ubuntu1 [19.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.28+6-1ubuntu1~22.04.1 [42.6 MB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-12-4 12.4.127-1 [1,200 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-12-4 12.4.127-1 [16.8 MB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-12-4 12.4.127-1 [3,830 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-12-4 12.4.127-1 [49.9 MB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ca-certificates-java all 20190909ubuntu1.2 [12.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.28+6-1ubuntu1~22.04.1 [214 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:29 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-12-4 12.4.127-1 [225 kB]
# Get:30 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-12-4 12.4.127-1 [4,920 kB]
# Get:31 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-12-4 12.4.127-1 [2,431 kB]
# Get:32 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-12-4 12.4.127-1 [51.5 kB]
# Get:33 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-12-4 12.4.127-1 [9,148 kB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-12-4 12.4.1-1 [2,538 B]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-12-4 12.4.127-1 [191 kB]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-4-config-common 12.4.127-1 [16.4 kB]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-12-4 12.4.127-1 [165 kB]
# Get:38 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-12-4 12.4.127-1 [28.6 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-12-4 12.4.127-1 [1,000 kB]
# Get:40 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvm-12-4 12.4.131-1 [19.5 MB]
# Get:41 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-crt-12-4 12.4.131-1 [78.0 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-12-4 12.4.131-1 [32.0 MB]
# Get:43 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-12-4 12.4.127-1 [58.8 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-12-4 12.4.1-1 [2,510 B]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-12-4 12.4.127-1 [50.0 kB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-12-4 12.4.127-1 [17.6 MB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-12-4 12.4.127-1 [24.0 kB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-12-4 12.4.5.8-1 [231 MB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-12-4 11.2.1.3-1 [171 MB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-12-4 1.9.1.3-1 [850 kB]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-12-4 10.3.5.147-1 [41.4 MB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-12-4 11.6.1.9-1 [78.9 MB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-12-4 12.3.1.170-1 [115 MB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-12-4 12.2.5.30-1 [95.5 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-12-4 12.4.127-1 [15.5 MB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-12-4 12.4.127-1 [721 kB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-12-4 12.3.1.117-1 [2,327 kB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-12-4 12.4.1-1 [2,606 B]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-12-4 12.4.127-1 [18.7 kB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-12-4 12.4.127-1 [16.9 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-dev-12-4 12.4.127-1 [87.0 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-12-4 12.4.5.8-1 [249 MB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-12-4 11.2.1.3-1 [342 MB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-12-4 1.9.1.3-1 [2,435 kB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-12-4 10.3.5.147-1 [41.6 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-12-4 11.6.1.9-1 [51.4 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-12-4 12.3.1.170-1 [116 MB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-12-4 12.2.5.30-1 [92.0 MB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-dev-12-4 12.4.127-1 [13.9 MB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-dev-12-4 12.4.127-1 [591 kB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-12-4 12.3.1.117-1 [2,025 kB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-12-4 12.4.1-1 [2,646 B]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-12-4 12.4.127-1 [119 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2024.1.1 2024.1.1.4-1 [594 MB]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-12-4 12.4.1-1 [4,060 B]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2023.4.4 2023.4.4.54-234433681190v0 [316 MB]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-12-4 12.4.1-1 [3,348 B]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-12-4 12.4.127-1 [145 kB]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-12-4 12.4.127-1 [115 MB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-12-4 12.4.1-1 [2,942 B]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-12-4 1.9.1.3-1 [39.0 MB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-12-4 12.4.1-1 [2,462 B]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-4 12.4.1-1 [3,336 B]
# Fetched 3,068 MB in 59s (51.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 83.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package java-common.
# (Reading database ... 125080 files and directories currently installed.)
# Preparing to unpack .../00-java-common_0.72build2_all.deb ...
# Unpacking java-common (0.72build2) ...
# Selecting previously unselected package libpcsclite1:amd64.
# Preparing to unpack .../01-libpcsclite1_1.9.5-3ubuntu1_amd64.deb ...
# Unpacking libpcsclite1:amd64 (1.9.5-3ubuntu1) ...
# Selecting previously unselected package openjdk-11-jre-headless:amd64.
# Preparing to unpack .../02-openjdk-11-jre-headless_11.0.28+6-1ubuntu1~22.04.1_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.28+6-1ubuntu1~22.04.1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../03-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package ca-certificates-java.
# Preparing to unpack .../04-ca-certificates-java_20190909ubuntu1.2_all.deb ...
# Unpacking ca-certificates-java (20190909ubuntu1.2) ...
# Selecting previously unselected package cuda-cccl-12-4.
# Preparing to unpack .../05-cuda-cccl-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cccl-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-cupti-12-4.
# Preparing to unpack .../06-cuda-cupti-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cupti-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-4.
# Preparing to unpack .../07-cuda-cupti-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-4.
# Preparing to unpack .../08-cuda-nvdisasm-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-4.
# Preparing to unpack .../09-cuda-cuobjdump-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-gdb-12-4.
# Preparing to unpack .../10-cuda-gdb-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-gdb-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvprof-12-4.
# Preparing to unpack .../11-cuda-nvprof-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvprof-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvtx-12-4.
# Preparing to unpack .../12-cuda-nvtx-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvtx-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-sanitizer-12-4.
# Preparing to unpack .../13-cuda-sanitizer-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-4.
# Preparing to unpack .../14-cuda-command-line-tools-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-4 (12.4.1-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-4.
# Preparing to unpack .../15-cuda-cuxxfilt-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-toolkit-12-4-config-common.
# Preparing to unpack .../16-cuda-toolkit-12-4-config-common_12.4.127-1_all.deb ...
# Unpacking cuda-toolkit-12-4-config-common (12.4.127-1) ...
# Selecting previously unselected package cuda-cudart-12-4.
# Preparing to unpack .../17-cuda-cudart-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cudart-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-driver-dev-12-4.
# Preparing to unpack .../18-cuda-driver-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-4.
# Preparing to unpack .../19-cuda-cudart-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvvm-12-4.
# Preparing to unpack .../20-cuda-nvvm-12-4_12.4.131-1_amd64.deb ...
# Unpacking cuda-nvvm-12-4 (12.4.131-1) ...
# Selecting previously unselected package cuda-crt-12-4.
# Preparing to unpack .../21-cuda-crt-12-4_12.4.131-1_amd64.deb ...
# Unpacking cuda-crt-12-4 (12.4.131-1) ...
# Selecting previously unselected package cuda-nvcc-12-4.
# Preparing to unpack .../22-cuda-nvcc-12-4_12.4.131-1_amd64.deb ...
# Unpacking cuda-nvcc-12-4 (12.4.131-1) ...
# Selecting previously unselected package cuda-nvprune-12-4.
# Preparing to unpack .../23-cuda-nvprune-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvprune-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-compiler-12-4.
# Preparing to unpack .../24-cuda-compiler-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-compiler-12-4 (12.4.1-1) ...
# Selecting previously unselected package cuda-documentation-12-4.
# Preparing to unpack .../25-cuda-documentation-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-documentation-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvrtc-12-4.
# Preparing to unpack .../26-cuda-nvrtc-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-opencl-12-4.
# Preparing to unpack .../27-cuda-opencl-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-opencl-12-4 (12.4.127-1) ...
# Selecting previously unselected package libcublas-12-4.
# Preparing to unpack .../28-libcublas-12-4_12.4.5.8-1_amd64.deb ...
# Unpacking libcublas-12-4 (12.4.5.8-1) ...
# Selecting previously unselected package libcufft-12-4.
# Preparing to unpack .../29-libcufft-12-4_11.2.1.3-1_amd64.deb ...
# Unpacking libcufft-12-4 (11.2.1.3-1) ...
# Selecting previously unselected package libcufile-12-4.
# Preparing to unpack .../30-libcufile-12-4_1.9.1.3-1_amd64.deb ...
# Unpacking libcufile-12-4 (1.9.1.3-1) ...
# Selecting previously unselected package libcurand-12-4.
# Preparing to unpack .../31-libcurand-12-4_10.3.5.147-1_amd64.deb ...
# Unpacking libcurand-12-4 (10.3.5.147-1) ...
# Selecting previously unselected package libcusolver-12-4.
# Preparing to unpack .../32-libcusolver-12-4_11.6.1.9-1_amd64.deb ...
# Unpacking libcusolver-12-4 (11.6.1.9-1) ...
# Selecting previously unselected package libcusparse-12-4.
# Preparing to unpack .../33-libcusparse-12-4_12.3.1.170-1_amd64.deb ...
# Unpacking libcusparse-12-4 (12.3.1.170-1) ...
# Selecting previously unselected package libnpp-12-4.
# Preparing to unpack .../34-libnpp-12-4_12.2.5.30-1_amd64.deb ...
# Unpacking libnpp-12-4 (12.2.5.30-1) ...
# Selecting previously unselected package libnvjitlink-12-4.
# Preparing to unpack .../35-libnvjitlink-12-4_12.4.127-1_amd64.deb ...
# Unpacking libnvjitlink-12-4 (12.4.127-1) ...
# Selecting previously unselected package libnvfatbin-12-4.
# Preparing to unpack .../36-libnvfatbin-12-4_12.4.127-1_amd64.deb ...
# Unpacking libnvfatbin-12-4 (12.4.127-1) ...
# Selecting previously unselected package libnvjpeg-12-4.
# Preparing to unpack .../37-libnvjpeg-12-4_12.3.1.117-1_amd64.deb ...
# Unpacking libnvjpeg-12-4 (12.3.1.117-1) ...
# Selecting previously unselected package cuda-libraries-12-4.
# Preparing to unpack .../38-cuda-libraries-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-libraries-12-4 (12.4.1-1) ...
# Selecting previously unselected package cuda-profiler-api-12-4.
# Preparing to unpack .../39-cuda-profiler-api-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-4.
# Preparing to unpack .../40-cuda-nvrtc-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-4.
# Preparing to unpack .../41-cuda-opencl-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package libcublas-dev-12-4.
# Preparing to unpack .../42-libcublas-dev-12-4_12.4.5.8-1_amd64.deb ...
# Unpacking libcublas-dev-12-4 (12.4.5.8-1) ...
# Selecting previously unselected package libcufft-dev-12-4.
# Preparing to unpack .../43-libcufft-dev-12-4_11.2.1.3-1_amd64.deb ...
# Unpacking libcufft-dev-12-4 (11.2.1.3-1) ...
# Selecting previously unselected package libcufile-dev-12-4.
# Preparing to unpack .../44-libcufile-dev-12-4_1.9.1.3-1_amd64.deb ...
# Unpacking libcufile-dev-12-4 (1.9.1.3-1) ...
# Selecting previously unselected package libcurand-dev-12-4.
# Preparing to unpack .../45-libcurand-dev-12-4_10.3.5.147-1_amd64.deb ...
# Unpacking libcurand-dev-12-4 (10.3.5.147-1) ...
# Selecting previously unselected package libcusolver-dev-12-4.
# Preparing to unpack .../46-libcusolver-dev-12-4_11.6.1.9-1_amd64.deb ...
# Unpacking libcusolver-dev-12-4 (11.6.1.9-1) ...
# Selecting previously unselected package libcusparse-dev-12-4.
# Preparing to unpack .../47-libcusparse-dev-12-4_12.3.1.170-1_amd64.deb ...
# Unpacking libcusparse-dev-12-4 (12.3.1.170-1) ...
# Selecting previously unselected package libnpp-dev-12-4.
# Preparing to unpack .../48-libnpp-dev-12-4_12.2.5.30-1_amd64.deb ...
# Unpacking libnpp-dev-12-4 (12.2.5.30-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-4.
# Preparing to unpack .../49-libnvjitlink-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package libnvfatbin-dev-12-4.
# Preparing to unpack .../50-libnvfatbin-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking libnvfatbin-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-4.
# Preparing to unpack .../51-libnvjpeg-dev-12-4_12.3.1.117-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-4 (12.3.1.117-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-4.
# Preparing to unpack .../52-cuda-libraries-dev-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-4 (12.4.1-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../53-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../54-openjdk-11-jre_11.0.28+6-1ubuntu1~22.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.28+6-1ubuntu1~22.04.1) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../55-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-12-4.
# Preparing to unpack .../56-cuda-nsight-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nsight-12-4 (12.4.127-1) ...
# Selecting previously unselected package nsight-compute-2024.1.1.
# Preparing to unpack .../57-nsight-compute-2024.1.1_2024.1.1.4-1_amd64.deb ...
# Unpacking nsight-compute-2024.1.1 (2024.1.1.4-1) ...
# Selecting previously unselected package cuda-nsight-compute-12-4.
# Preparing to unpack .../58-cuda-nsight-compute-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-nsight-compute-12-4 (12.4.1-1) ...
# Selecting previously unselected package libtinfo5:amd64.
# Preparing to unpack .../59-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../60-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../61-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../62-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../63-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../64-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../65-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../66-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../67-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../68-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package nsight-systems-2023.4.4.
# Preparing to unpack .../69-nsight-systems-2023.4.4_2023.4.4.54-234433681190v0_amd64.deb ...
# Unpacking nsight-systems-2023.4.4 (2023.4.4.54-234433681190v0) ...
# Selecting previously unselected package cuda-nsight-systems-12-4.
# Preparing to unpack .../70-cuda-nsight-systems-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-nsight-systems-12-4 (12.4.1-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-4.
# Preparing to unpack .../71-cuda-nvml-dev-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-nvvp-12-4.
# Preparing to unpack .../72-cuda-nvvp-12-4_12.4.127-1_amd64.deb ...
# Unpacking cuda-nvvp-12-4 (12.4.127-1) ...
# Selecting previously unselected package cuda-visual-tools-12-4.
# Preparing to unpack .../73-cuda-visual-tools-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-4 (12.4.1-1) ...
# Selecting previously unselected package gds-tools-12-4.
# Preparing to unpack .../74-gds-tools-12-4_1.9.1.3-1_amd64.deb ...
# Unpacking gds-tools-12-4 (1.9.1.3-1) ...
# Selecting previously unselected package cuda-tools-12-4.
# Preparing to unpack .../75-cuda-tools-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-tools-12-4 (12.4.1-1) ...
# Selecting previously unselected package cuda-toolkit-12-4.
# Preparing to unpack .../76-cuda-toolkit-12-4_12.4.1-1_amd64.deb ...
# Unpacking cuda-toolkit-12-4 (12.4.1-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../77-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../78-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../79-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../80-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../81-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../82-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-cupti-12-4 (12.4.127-1) ...
# Setting up cuda-nvml-dev-12-4 (12.4.127-1) ...
# Setting up cuda-cccl-12-4 (12.4.127-1) ...
# Setting up java-common (0.72build2) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cupti-dev-12-4 (12.4.127-1) ...
# Setting up gds-tools-12-4 (1.9.1.3-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-documentation-12-4 (12.4.127-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up cuda-profiler-api-12-4 (12.4.127-1) ...
# Setting up cuda-nvdisasm-12-4 (12.4.127-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up cuda-nvvm-12-4 (12.4.131-1) ...
# Setting up cuda-nvprune-12-4 (12.4.127-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvtx-12-4 (12.4.127-1) ...
# Setting up cuda-cuxxfilt-12-4 (12.4.127-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libpcsclite1:amd64 (1.9.5-3ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up nsight-compute-2024.1.1 (2024.1.1.4-1) ...
# Setting up cuda-driver-dev-12-4 (12.4.127-1) ...
# Setting up cuda-nvprof-12-4 (12.4.127-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up cuda-cuobjdump-12-4 (12.4.127-1) ...
# Setting up cuda-toolkit-12-4-config-common (12.4.127-1) ...
# Setting alternatives
# update-alternatives: warning: forcing reinstallation of alternative /usr/local/cuda-12.5 because link group cuda is broken
# Setting up libnvjitlink-12-4 (12.4.127-1) ...
# Setting up cuda-nvrtc-12-4 (12.4.127-1) ...
# Setting up cuda-sanitizer-12-4 (12.4.127-1) ...
# Setting up libcurand-12-4 (10.3.5.147-1) ...
# Setting up libnpp-12-4 (12.2.5.30-1) ...
# Setting up libcufft-12-4 (11.2.1.3-1) ...
# Setting up libnvjitlink-dev-12-4 (12.4.127-1) ...
# Setting up libcublas-12-4 (12.4.5.8-1) ...
# Setting up libcusparse-12-4 (12.3.1.170-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libnvfatbin-12-4 (12.4.127-1) ...
# Setting up libcurand-dev-12-4 (10.3.5.147-1) ...
# Setting up libnvjpeg-12-4 (12.3.1.117-1) ...
# Setting up cuda-nsight-compute-12-4 (12.4.1-1) ...
# Setting up libcufile-12-4 (1.9.1.3-1) ...
# Setting alternatives
# Setting up nsight-systems-2023.4.4 (2023.4.4.54-234433681190v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2023.4.4/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2023.4.4/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libnpp-dev-12-4 (12.2.5.30-1) ...
# Setting up cuda-opencl-12-4 (12.4.127-1) ...
# Setting up libcusparse-dev-12-4 (12.3.1.170-1) ...
# Setting up cuda-nvrtc-dev-12-4 (12.4.127-1) ...
# Setting up libcublas-dev-12-4 (12.4.5.8-1) ...
# Setting up cuda-cudart-12-4 (12.4.127-1) ...
# Setting up cuda-gdb-12-4 (12.4.127-1) ...
# Setting up libcusolver-12-4 (11.6.1.9-1) ...
# Setting up cuda-libraries-12-4 (12.4.1-1) ...
# Setting up cuda-nsight-systems-12-4 (12.4.1-1) ...
# Setting up libcusolver-dev-12-4 (11.6.1.9-1) ...
# Setting up libcufft-dev-12-4 (11.2.1.3-1) ...
# Setting up cuda-command-line-tools-12-4 (12.4.1-1) ...
# Setting up cuda-opencl-dev-12-4 (12.4.127-1) ...
# Setting up libnvfatbin-dev-12-4 (12.4.127-1) ...
# Setting up cuda-cudart-dev-12-4 (12.4.127-1) ...
# Setting up cuda-crt-12-4 (12.4.131-1) ...
# Setting up libnvjpeg-dev-12-4 (12.3.1.117-1) ...
# Setting up libcufile-dev-12-4 (1.9.1.3-1) ...
# Setting up cuda-nvcc-12-4 (12.4.131-1) ...
# Setting up cuda-compiler-12-4 (12.4.1-1) ...
# Setting up cuda-libraries-dev-12-4 (12.4.1-1) ...
# Setting up ca-certificates-java (20190909ubuntu1.2) ...
# head: cannot open '/etc/ssl/certs/java/cacerts' for reading: No such file or directory
# Adding debian:GDCA_TrustAUTH_R5_ROOT.pem
# Adding debian:CA_Disig_Root_R2.pem
# Adding debian:COMODO_Certification_Authority.pem
# Adding debian:Go_Daddy_Root_Certificate_Authority_-_G2.pem
# Adding debian:SSL.com_EV_Root_Certification_Authority_ECC.pem
# Adding debian:Secure_Global_CA.pem
# Adding debian:GlobalSign_Root_CA_-_R3.pem
# Adding debian:GTS_Root_R3.pem
# Adding debian:UCA_Global_G2_Root.pem
# Adding debian:Certigna_Root_CA.pem
# Adding debian:Trustwave_Global_ECC_P384_Certification_Authority.pem
# Adding debian:DigiCert_Global_Root_G2.pem
# Adding debian:D-TRUST_Root_Class_3_CA_2_2009.pem
# Adding debian:OISTE_WISeKey_Global_Root_GB_CA.pem
# Adding debian:QuoVadis_Root_CA_2.pem
# Adding debian:Security_Communication_RootCA3.pem
# Adding debian:SwissSign_Silver_CA_-_G2.pem
# Adding debian:Hongkong_Post_Root_CA_3.pem
# Adding debian:Comodo_AAA_Services_root.pem
# Adding debian:T-TeleSec_GlobalRoot_Class_2.pem
# Adding debian:TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1.pem
# Adding debian:emSign_ECC_Root_CA_-_C3.pem
# Adding debian:Microsec_e-Szigno_Root_CA_2009.pem
# Adding debian:USERTrust_ECC_Certification_Authority.pem
# Adding debian:Starfield_Services_Root_Certificate_Authority_-_G2.pem
# Adding debian:AffirmTrust_Premium_ECC.pem
# Adding debian:e-Szigno_Root_CA_2017.pem
# Adding debian:GLOBALTRUST_2020.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_ECC_RootCA_2015.pem
# Adding debian:Starfield_Root_Certificate_Authority_-_G2.pem
# Adding debian:emSign_Root_CA_-_G1.pem
# Adding debian:Certum_Trusted_Root_CA.pem
# Adding debian:GlobalSign_ECC_Root_CA_-_R5.pem
# Adding debian:vTrus_Root_CA.pem
# Adding debian:ISRG_Root_X2.pem
# Adding debian:HiPKI_Root_CA_-_G1.pem
# Adding debian:GTS_Root_R1.pem
# Adding debian:Security_Communication_Root_CA.pem
# Adding debian:TWCA_Root_Certification_Authority.pem
# Adding debian:AC_RAIZ_FNMT-RCM.pem
# Adding debian:Telia_Root_CA_v2.pem
# Adding debian:certSIGN_Root_CA_G2.pem
# Adding debian:Certum_Trusted_Network_CA_2.pem
# Adding debian:Entrust_Root_Certification_Authority_-_EC1.pem
# Adding debian:QuoVadis_Root_CA_2_G3.pem
# Adding debian:ePKI_Root_Certification_Authority.pem
# Adding debian:SecureSign_RootCA11.pem
# Adding debian:Entrust_Root_Certification_Authority.pem
# Adding debian:SecureTrust_CA.pem
# Adding debian:OISTE_WISeKey_Global_Root_GC_CA.pem
# Adding debian:GlobalSign_Root_R46.pem
# Adding debian:Amazon_Root_CA_3.pem
# Adding debian:DigiCert_Assured_ID_Root_CA.pem
# Adding debian:emSign_ECC_Root_CA_-_G3.pem
# Adding debian:USERTrust_RSA_Certification_Authority.pem
# Adding debian:Atos_TrustedRoot_2011.pem
# Adding debian:Certum_Trusted_Network_CA.pem
# Adding debian:IdenTrust_Commercial_Root_CA_1.pem
# Adding debian:D-TRUST_BR_Root_CA_1_2020.pem
# Adding debian:Entrust_Root_Certification_Authority_-_G2.pem
# Adding debian:HARICA_TLS_ECC_Root_CA_2021.pem
# Adding debian:Buypass_Class_2_Root_CA.pem
# Adding debian:Certainly_Root_R1.pem
# Adding debian:ACCVRAIZ1.pem
# Adding debian:Trustwave_Global_ECC_P256_Certification_Authority.pem
# Adding debian:AffirmTrust_Networking.pem
# Adding debian:ANF_Secure_Server_Root_CA.pem
# Adding debian:Entrust_Root_Certification_Authority_-_G4.pem
# Adding debian:NetLock_Arany_=Class_Gold=_Főtanúsítvány.pem
# Adding debian:NAVER_Global_Root_Certification_Authority.pem
# Adding debian:DigiCert_TLS_RSA4096_Root_G5.pem
# Adding debian:QuoVadis_Root_CA_3_G3.pem
# Adding debian:IdenTrust_Public_Sector_Root_CA_1.pem
# Adding debian:D-TRUST_EV_Root_CA_1_2020.pem
# Adding debian:COMODO_ECC_Certification_Authority.pem
# Adding debian:XRamp_Global_CA_Root.pem
# Adding debian:vTrus_ECC_Root_CA.pem
# Adding debian:DigiCert_Assured_ID_Root_G3.pem
# Adding debian:AffirmTrust_Commercial.pem
# Adding debian:DigiCert_High_Assurance_EV_Root_CA.pem
# Adding debian:DigiCert_Assured_ID_Root_G2.pem
# Adding debian:emSign_Root_CA_-_C1.pem
# Adding debian:Microsoft_RSA_Root_Certificate_Authority_2017.pem
# Adding debian:T-TeleSec_GlobalRoot_Class_3.pem
# Adding debian:Go_Daddy_Class_2_CA.pem
# Adding debian:DigiCert_Global_Root_G3.pem
# Adding debian:Autoridad_de_Certificacion_Firmaprofesional_CIF_A62634068.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_RootCA_2015.pem
# Adding debian:Certigna.pem
# Adding debian:Security_Communication_RootCA2.pem
# Adding debian:Amazon_Root_CA_1.pem
# Adding debian:GlobalSign_Root_E46.pem
# Adding debian:Entrust.net_Premium_2048_Secure_Server_CA.pem
# Adding debian:GTS_Root_R2.pem
# Adding debian:Trustwave_Global_Certification_Authority.pem
# Adding debian:Starfield_Class_2_CA.pem
# Adding debian:AC_RAIZ_FNMT-RCM_SERVIDORES_SEGUROS.pem
# Adding debian:GlobalSign_Root_CA.pem
# Adding debian:HARICA_TLS_RSA_Root_CA_2021.pem
# Adding debian:Buypass_Class_3_Root_CA.pem
# Adding debian:GlobalSign_ECC_Root_CA_-_R4.pem
# Adding debian:Izenpe.com.pem
# Adding debian:certSIGN_ROOT_CA.pem
# Adding debian:CFCA_EV_ROOT.pem
# Adding debian:SSL.com_Root_Certification_Authority_ECC.pem
# Adding debian:D-TRUST_Root_Class_3_CA_2_EV_2009.pem
# Adding debian:DigiCert_TLS_ECC_P384_Root_G5.pem
# Adding debian:QuoVadis_Root_CA_1_G3.pem
# Adding debian:TunTrust_Root_CA.pem
# Adding debian:SZAFIR_ROOT_CA2.pem
# Adding debian:SSL.com_EV_Root_Certification_Authority_RSA_R2.pem
# Adding debian:GlobalSign_Root_CA_-_R6.pem
# Adding debian:Security_Communication_ECC_RootCA1.pem
# Adding debian:Certainly_Root_E1.pem
# Adding debian:SSL.com_Root_Certification_Authority_RSA.pem
# Adding debian:Certum_EC-384_CA.pem
# Adding debian:DigiCert_Global_Root_CA.pem
# Adding debian:UCA_Extended_Validation_Root.pem
# Adding debian:Microsoft_ECC_Root_Certificate_Authority_2017.pem
# Adding debian:DigiCert_Trusted_Root_G4.pem
# Adding debian:AffirmTrust_Premium.pem
# Adding debian:SwissSign_Gold_CA_-_G2.pem
# Adding debian:QuoVadis_Root_CA_3.pem
# Adding debian:Actalis_Authentication_Root_CA.pem
# Adding debian:ISRG_Root_X1.pem
# Adding debian:TWCA_Global_Root_CA.pem
# Adding debian:Amazon_Root_CA_4.pem
# Adding debian:TeliaSonera_Root_CA_v1.pem
# Adding debian:Amazon_Root_CA_2.pem
# Adding debian:Baltimore_CyberTrust_Root.pem
# Adding debian:COMODO_RSA_Certification_Authority.pem
# Adding debian:GTS_Root_R4.pem
# Adding debian:SSL.com_TLS_ECC_Root_CA_2022.pem
# Adding debian:CommScope_Public_Trust_RSA_Root-02.pem
# Adding debian:CommScope_Public_Trust_RSA_Root-01.pem
# Adding debian:Sectigo_Public_Server_Authentication_Root_E46.pem
# Adding debian:BJCA_Global_Root_CA1.pem
# Adding debian:TrustAsia_Global_Root_CA_G3.pem
# Adding debian:Sectigo_Public_Server_Authentication_Root_R46.pem
# Adding debian:CommScope_Public_Trust_ECC_Root-01.pem
# Adding debian:CommScope_Public_Trust_ECC_Root-02.pem
# Adding debian:Atos_TrustedRoot_Root_CA_RSA_TLS_2021.pem
# Adding debian:BJCA_Global_Root_CA2.pem
# Adding debian:Atos_TrustedRoot_Root_CA_ECC_TLS_2021.pem
# Adding debian:SSL.com_TLS_RSA_Root_CA_2022.pem
# Adding debian:TrustAsia_Global_Root_CA_G4.pem
# done.
# Setting up default-jre-headless (2:1.11-72build2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for ca-certificates (20240203~22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# done.
# done.
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.28+6-1ubuntu1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/rmid to provide /usr/bin/rmid (rmid) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/pack200 to provide /usr/bin/pack200 (pack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/unpack200 to provide /usr/bin/unpack200 (unpack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up openjdk-11-jre:amd64 (11.0.28+6-1ubuntu1~22.04.1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-nsight-12-4 (12.4.127-1) ...
# Setting up cuda-nvvp-12-4 (12.4.127-1) ...
# Setting up cuda-visual-tools-12-4 (12.4.1-1) ...
# Setting up cuda-tools-12-4 (12.4.1-1) ...
# Setting up cuda-toolkit-12-4 (12.4.1-1) ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Mar_28_02:18:24_PDT_2024
# Cuda compilation tools, release 12.4, V12.4.131
# Build cuda_12.4.r12.4/compiler.34097967_0

# %%
# %%writefile
